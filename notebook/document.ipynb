# %% [markdown]
# **Data Ingestion**

# %%
from langchain_core.documents import Document

# %%
doc = Document(
    page_content = "This is the main text content I am using to create RAG",
    metadata = {
        "Source":"8th sem syllbus",
        "Pages":"8",
        "author":"CSVTU..",
        "date_created":"25-08-2026"
    }
)
doc
# Out:
# Document(metadata={'Source': '8th sem syllbus', 'Pages': '8', 'author': 'CSVTU..', 'date_created': '25-08-2026'}, page_content='This is the main text content I am using to create RAG')

# %%
### TextLoder

from langchain_community.document_loaders import TextLoader

loader = TextLoader("../data/text_files/rag_intro.txt",encoding="utf-8")
loader

documents = loader.load()

print(documents)
# Out:
# [Document(metadata={'source': '../data/text_files/rag_intro.txt'}, page_content='A typical RAG system looks like:\n\nDocuments → Loading → Splitting/Chunking → Embeddings → Vector Database → Retrieval → Prompt → LLM → Answer\n\nAnd then you can extend it with reranking, conversation memory, agents, tools, evaluation, and production deployment.\n\nRAG topics in the right learning order\n1. Python fundamentals\n\nBefore RAG, be comfortable with:\n\nFunctions\nClasses/OOP\nLists, dictionaries, sets\nFile handling\nExceptions\nVirtual environments\npip / uv\nAPIs and JSON\nEnvironment variables\n\nImplementation: Build a small Python program that reads a text/PDF file and processes its contents.\n\n2. LLM fundamentals\n\nUnderstand:\n\nWhat an LLM is\nTokens\nContext window\nPrompt\nTemperature\nSystem/user messages\nChat models\nAPI-based vs local models\nHugging Face models\nOllama/local LLMs\n\nImplementation: Create a simple chatbot using an LLM API or Ollama.\n\n3. Document Loaders\
# ...

# %%
### Directory Loader

from langchain_community.document_loaders import DirectoryLoader

## load all the text files from the directory
dir_loader=DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt", ## Pattern to match files  
    loader_cls= TextLoader, ##loader class to use
    loader_kwargs={'encoding': 'utf-8'},
    show_progress=False

)

documents = dir_loader.load()
documents
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\Claude_Ollama_Setup.txt'}, page_content='how to use cloude for vibe coding and running the prohject, i already download the clopue and olama\n\nYes. If you already have **Claude Desktop** and **Ollama**, you can use them together for vibe coding, but they serve different purposes:\n\n* **Claude** → your AI coding assistant: understands your project, writes/edits code, debugs, explains errors.\n* **Ollama** → runs AI models locally on your PC. Good for free/local coding assistance.\n* **VS Code** → where you actually open and run your project.\n\n### 1. Easiest setup for vibe coding\n\nI recommend this setup:\n\n**VS Code + Claude Code + Ollama**\n\nIf by “Claude” you mean **Claude Desktop**, there is an important distinction: Claude Desktop itself isn\'t the same thing as **Claude Code**, which is designed specifically to work with your codebase and terminal.\n\nFor your type of work—coding, debugging, modifying projects—I would us
# ...

# %%
### load all the text files from the pdfs 

from langchain_community.document_loaders import DirectoryLoader, PyPDFLoader
dir_loader=DirectoryLoader(
    "../data/pdf",
    glob="**/*.pdf", ## Pattern to match files  
    loader_cls=PyPDFLoader, ##loader class to use
    show_progress=False

)

pdf_documents = dir_loader.load()
pdf_documents
# Out:
# [Document(metadata={'producer': 'SmartSoft PDF Printer 5.1.0.369', 'creator': 'Microsoft Word - BTech_CSE_Sylabusut', 'creationdate': '2023-05-17T17:21:03+05:30', 'moddate': '2023-05-17T17:21:10+05:30', 'source': '..\\data\\pdf\\8_Sem_BTech_CSE.pdf', 'total_pages': 8, 'page': 0, 'page_label': '1'}, page_content='h r a g s i t t a h h C im awS  a d n a n akev i V  l a c i n h c e T , y t i sre v i n U i a l i h B \ne g a P\t1\t f o\t8\t\n \n \n \nmarg orP  / :re t s emeS  h ceT.B  I I IV(  )m eS  :hcnarB  r etu pmoC  e cne i cS  & g ni reeni gnE  \n: t cej b u S re byC  waL  d na  l au tc e l l et n I  ytreporP  esru oC  :e d oC  )2 2 0(118 2 20D  \nmumini M  /  l a t oT - s sa P skr a M dnE ( r e t semeS  : )maxE  0 0 1 / 53  : L 3 : T 1 :P  0 :st ide r C 4 \ns s alC  s t s e T & s tnemn g i s sA  ot  eb  :de t cud noc  2 hca e n oit aru D  d nE (  ret semeS  : )maxE  30  sruoH  \nesruo C  : sevitc ej bO  \n.1  oT  ekam  evit ne tta  ot  s tned ut s  tuoba  tne r e f f id  semi r c r
# ...

# %%
type(pdf_documents[0])
# Out:
# langchain_core.documents.base.Document

# %%
### load word file

from langchain_community.document_loaders import Docx2txtLoader

loader = Docx2txtLoader("../data/word_files/Unit_I-1.docx")

documents = loader.load()
print(len(documents))
print(documents[0].page_content)
print(documents[0].metadata)
# Out:
# 1
# Unit I: Introduction
#
#
#
# Introduction to Programming,
#
#  Introduction to components of a computer system (disks, memory, processor,
#
# where a program is stored and executed,
#
# operating system,
#
# compilers
#
# Idea of Algorithm: steps to solve logical and numerical problems. Representation of Algorithm:
#
# Flowchart,
#
# Pseudo code and Source code with examples.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 1.Introduction to Programming,
#
# COMPUTER PROGRAMMING is a step by step process of designing and developing various sets of computer programs to accomplish a specific computing outcome.
#
# The process comprises several tasks like
#
# analysis,
#
# coding,
#
# algorithm generation,
#
# checking accuracy
#
# and resource consumption of algorithms, etc.
#
#  The purpose of computer programming is to find a sequence of instructions that solve a specific problem on a computer.
#
# ...
